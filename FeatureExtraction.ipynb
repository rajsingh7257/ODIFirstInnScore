# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('finaldata.pkl','rb'))
df
# Out:
#      match_id  batting_team  bowling_team  ball  runs player_dismissed  \
# 0           2   West Indies  South Africa   0.1     0                0
# 1           2   West Indies  South Africa   0.2     1                0
# 2           2   West Indies  South Africa   0.3     1                0
# 3           2   West Indies  South Africa   0.4     0                0
# 4           2   West Indies  South Africa   0.5     0                0
# ..        ...           ...           ...   ...   ...              ...
# 302      1682  South Africa     Sri Lanka  49.5     0                0
# 303      1682  South Africa     Sri Lanka  49.6     1                0
# 304      1682  South Africa     Sri Lanka  49.7     1                0
# 305      1682  South Africa     Sri Lanka  49.8     1                0
# 306      1682  South Africa     Sri Lanka  49.9     1                0
#
#           city                  venue
# 0      Jamaica  Sabina Park, Kingston
# ...

# %%
df.isnull().sum()
# Out:
# match_id                0
# batting_team            0
# bowling_team            0
# ball                    0
# runs                    0
# player_dismissed        0
# city                70142
# venue                   0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Harare Sports Club                         13787
# Rangiri Dambulla International Stadium      9436
# Sydney Cricket Ground                       9372
# Melbourne Cricket Ground                    7780
# Adelaide Oval                               7146
# Pallekele International Cricket Stadium     6472
# Dubai International Cricket Stadium         6008
# Sharjah Cricket Stadium                     3756
# Rawalpindi Cricket Stadium                  1513
# Multan Cricket Stadium                      1509
# Queenstown Events Centre                     909
# Chittagong Divisional Stadium                900
# Dubai Sports City Cricket Stadium            518
# Galle International Stadium                  513
# Sheikhupura Stadium                          291
# Perth Stadium                                232
# Name: venue, dtype: int64

# %%
df['city']=np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop('venue',axis=1,inplace=True)

# %%
df['city'].value_counts()[df['city'].value_counts() > 1500].sum()
# Out:
# 362697

# %%
eligible = df['city'].value_counts()[df['city'].value_counts() > 1500].index.to_list()

# %%
df = df[df['city'].isin(eligible)]
df
# Out:
#      match_id  batting_team  bowling_team  ball  runs player_dismissed  \
# 0           2   West Indies  South Africa   0.1     0                0
# 1           2   West Indies  South Africa   0.2     1                0
# 2           2   West Indies  South Africa   0.3     1                0
# 3           2   West Indies  South Africa   0.4     0                0
# 4           2   West Indies  South Africa   0.5     0                0
# ..        ...           ...           ...   ...   ...              ...
# 302      1682  South Africa     Sri Lanka  49.5     0                0
# 303      1682  South Africa     Sri Lanka  49.6     1                0
# 304      1682  South Africa     Sri Lanka  49.7     1                0
# 305      1682  South Africa     Sri Lanka  49.8     1                0
# 306      1682  South Africa     Sri Lanka  49.9     1                0
#
#           city
# 0      Jamaica
# 1      Jamaica
# 2      Jamaica
# 3      Jamaica
# 4      Jamaica
# ..         ...
# ...

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']
df
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_19036\2376281617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']
#      match_id  batting_team  bowling_team  ball  runs player_dismissed  \
# 0           2   West Indies  South Africa   0.1     0                0
# 1           2   West Indies  South Africa   0.2     1                0
# 2           2   West Indies  South Africa   0.3     1                0
# 3           2   West Indies  South Africa   0.4     0                0
# 4           2   West Indies  South Africa   0.5     0                0
# ..        ...           ...           ...   ...   ...              ...
# ...

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_19036\1757844946.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\72raj\AppData\Local\Temp\ipykernel_19036\1757844946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])

# %%
df
# Out:
#      match_id  batting_team  bowling_team  ball  runs player_dismissed  \
# 0           2   West Indies  South Africa   0.1     0                0
# 1           2   West Indies  South Africa   0.2     1                0
# 2           2   West Indies  South Africa   0.3     1                0
# 3           2   West Indies  South Africa   0.4     0                0
# 4           2   West Indies  South Africa   0.5     0                0
# ..        ...           ...           ...   ...   ...              ...
# 302      1682  South Africa     Sri Lanka  49.5     0                0
# 303      1682  South Africa     Sri Lanka  49.6     1                0
# 304      1682  South Africa     Sri Lanka  49.7     1                0
# 305      1682  South Africa     Sri Lanka  49.8     1                0
# 306      1682  South Africa     Sri Lanka  49.9     1                0
#
#           city  current_score over ball_no
# 0      Jamaica              0    0       1
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype(int)
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_19036\2226078376.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype(int)

# %%
df['balls_left'] = 300 - df['balls_bowled']
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_19036\1269980702.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 300 - df['balls_bowled']

# %%
df
# Out:
#      match_id  batting_team  bowling_team  ball  runs player_dismissed  \
# 0           2   West Indies  South Africa   0.1     0                0
# 1           2   West Indies  South Africa   0.2     1                0
# 2           2   West Indies  South Africa   0.3     1                0
# 3           2   West Indies  South Africa   0.4     0                0
# 4           2   West Indies  South Africa   0.5     0                0
# ..        ...           ...           ...   ...   ...              ...
# 302      1682  South Africa     Sri Lanka  49.5     0                0
# 303      1682  South Africa     Sri Lanka  49.6     1                0
# 304      1682  South Africa     Sri Lanka  49.7     1                0
# 305      1682  South Africa     Sri Lanka  49.8     1                0
# 306      1682  South Africa     Sri Lanka  49.9     1                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# ...

# %%
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_19036\3511862288.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#      match_id  batting_team  bowling_team  ball  runs player_dismissed  \
# 0           2   West Indies  South Africa   0.1     0                0
# 1           2   West Indies  South Africa   0.2     1                0
# 2           2   West Indies  South Africa   0.3     1                0
# 3           2   West Indies  South Africa   0.4     0                0
# 4           2   West Indies  South Africa   0.5     0                0
# ..        ...           ...           ...   ...   ...              ...
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x == '0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype(int)
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
df
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_19036\1947954636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x == '0' else 1)
# C:\Users\72raj\AppData\Local\Temp\ipykernel_19036\1947954636.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype(int)
# C:\Users\72raj\AppData\Local\Temp\ipykernel_19036\1947954636.py:3: SettingWithCopyWarning:
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
df
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_19036\1226876470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']
#      match_id  batting_team  bowling_team  ball  runs  player_dismissed  \
# 0           2   West Indies  South Africa   0.1     0                 0
# 1           2   West Indies  South Africa   0.2     1                 0
# 2           2   West Indies  South Africa   0.3     1                 0
# 3           2   West Indies  South Africa   0.4     0                 0
# 4           2   West Indies  South Africa   0.5     0                 0
# ..        ...           ...           ...   ...   ...               ...
# ...

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_19036\3055083752.py:6: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_19036\1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df
# Out:
#      match_id  batting_team  bowling_team  ball  runs  player_dismissed  \
# 0           2   West Indies  South Africa   0.1     0                 0
# 1           2   West Indies  South Africa   0.2     1                 0
# 2           2   West Indies  South Africa   0.3     1                 0
# 3           2   West Indies  South Africa   0.4     0                 0
# 4           2   West Indies  South Africa   0.5     0                 0
# ..        ...           ...           ...   ...   ...               ...
# 302      1682  South Africa     Sri Lanka  49.5     0                 6
# 303      1682  South Africa     Sri Lanka  49.6     1                 6
# 304      1682  South Africa     Sri Lanka  49.7     1                 6
# 305      1682  South Africa     Sri Lanka  49.8     1                 6
# 306      1682  South Africa     Sri Lanka  49.9     1                 6
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'runs_x', 'batting_team', 'bowling_team', 'ball', 'runs_y',
#        'player_dismissed', 'city', 'current_score', 'over', 'ball_no',
#        'balls_bowled', 'balls_left', 'wickets_left', 'crr', 'last_five'],
#       dtype='object')

# %%
df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
df = df[['match_id','batting_team', 'bowling_team','city','balls_left', 'wickets_left', 'crr', 'last_five','runs_x' ]]
df.rename(columns={'runs_x':'final_score'})
# Out:
#         match_id  batting_team  bowling_team       city  balls_left  \
# 0              2   West Indies  South Africa    Jamaica         299
# 1              2   West Indies  South Africa    Jamaica         298
# 2              2   West Indies  South Africa    Jamaica         297
# 3              2   West Indies  South Africa    Jamaica         296
# 4              2   West Indies  South Africa    Jamaica         295
# ...          ...           ...           ...        ...         ...
# 362692      1682  South Africa     Sri Lanka  Centurion           1
# 362693      1682  South Africa     Sri Lanka  Centurion           0
# 362694      1682  South Africa     Sri Lanka  Centurion           0
# 362695      1682  South Africa     Sri Lanka  Centurion           0
# 362696      1682  South Africa     Sri Lanka  Centurion           0
#
#         wickets_left       crr  last_five  final_score
# 0                 10  0.000000        NaN          152
# ...

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['match_id', 'batting_team', 'bowling_team', 'city', 'balls_left',
#        'wickets_left', 'crr', 'last_five', 'runs_x'],
#       dtype='object')

# %%
df = df.sample(df.shape[0])

# %%
X = df[['batting_team', 'bowling_team', 'city', 'balls_left',
       'wickets_left', 'crr', 'last_five']]
Y = df[['runs_x']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state = 1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
# !pip install xgboost
# Out:
# ...
#      ---------------------------------------- 89.1/89.1 MB 1.7 MB/s eta 0:00:00
# ...

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,Y_train)
Y_pred = pipe.predict(X_test)
print(r2_score(Y_test,Y_pred))
print(mean_absolute_error(Y_test,Y_pred))
# Out:
# 0.9885625085688587
# 2.7833801372322493

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
eligible
# Out:
# ['Mirpur',
#  'Colombo',
#  'London',
#  'Harare',
#  'Sydney',
#  'Rangiri',
#  'Abu Dhabi',
#  'Melbourne',
#  'Centurion',
#  'Bulawayo',
#  'Adelaide',
#  'Johannesburg',
#  'Dubai',
#  'Perth',
#  'Brisbane',
#  'Auckland',
#  'Pallekele',
#  'Wellington',
#  'Birmingham',
#  'Durban',
#  'Port Elizabeth',
#  'Nottingham',
#  'Cape Town',
#  'Manchester',
#  'Trinidad',
#  'Antigua',
#  'Hambantota',
#  'Karachi',
#  'Hamilton',
#  'Southampton',
#  'Jamaica',
#  'Chandigarh',
#  'Cardiff',
#  'Napier',
#  'Sharjah',
#  'Christchurch',
#  'Guyana',
#  'St Lucia',
#  'Mumbai',
#  'Leeds',
#  'St Kitts',
#  'Chester-le-Street',
#  'Ahmedabad',
#  'Lahore',
#  'Chittagong',
#  'Barbados',
#  'Grenada',
#  'Hobart',
#  'Dhaka',
#  'Jaipur',
#  'Chennai',
#  'Mount Maunganui',
#  'Nagpur',
#  'Delhi',
#  'Bloemfontein',
#  'Visakhapatnam',
#  'St Vincent',
#  'Dunedin',
#  'Rajkot',
#  'Hyderabad',
#  'Kanpur',
#  'Potchefstroom',
#  'Fatullah',
#  'Bristol',
#  'Kuala Lumpur',
# ...
