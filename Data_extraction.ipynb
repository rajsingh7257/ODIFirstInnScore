# %%
import pandas as pd
import numpy as np
from yaml import safe_load
import os
from tqdm import tqdm
import pickle

# %%
from pandas.io.json import json_normalize

# %%
filename = []
for file in os.listdir(r"C:\Users\72raj\Downloads\Test"):
    filename.append(os.path.join(r'C:\Users\72raj\Downloads\Test',file))

# %%
filename[0:5]
# Out:
# ['C:\\Users\\72raj\\Downloads\\Test\\208835.yaml',
#  'C:\\Users\\72raj\\Downloads\\Test\\209339.yaml',
#  'C:\\Users\\72raj\\Downloads\\Test\\209582.yaml',
#  'C:\\Users\\72raj\\Downloads\\Test\\209768.yaml',
#  'C:\\Users\\72raj\\Downloads\\Test\\211244.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filename):
    with open(file,'r') as f:
        x = safe_load(f)
        df = pd.json_normalize(x)
        match_id = counter
        final_df = final_df.append(df)
        counter+=1
# Out:
#   0%|                                                                                          | 0/500 [00:00<?, ?it/s]C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\3910070996.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|▏                                                                                 | 1/500 [00:00<06:51,  1.21it/s]C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\3910070996.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# ...

# %%
filename1 = []
for file in os.listdir(r"C:\Users\72raj\Downloads\Test1"):
    filename1.append(os.path.join(r'C:\Users\72raj\Downloads\Test1',file))

# %%
counter = 501
for file in tqdm(filename1):
    with open(file,'r') as f:
        x = safe_load(f)
        df = pd.json_normalize(x)
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
# Out:
#   0%|                                                                                          | 0/500 [00:00<?, ?it/s]C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\788467572.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|▏                                                                                 | 1/500 [00:01<11:46,  1.42s/it]C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\788467572.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# ...

# %%
filename2 = []
for file in os.listdir(r"C:\Users\72raj\Downloads\Test2"):
    filename2.append(os.path.join(r'C:\Users\72raj\Downloads\Test2',file))

# %%
counter = 1001
for file in tqdm(filename2):
    with open(file,'r') as f:
        x = safe_load(f)
        df = pd.json_normalize(x)
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
# Out:
#   0%|                                                                                          | 0/200 [00:00<?, ?it/s]C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\744321275.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|▍                                                                                 | 1/200 [00:01<03:40,  1.11s/it]C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\744321275.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1200 entries, 0 to 0
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   innings                      1200 non-null   object
#  1   meta.data_version            1200 non-null   float64
#  2   meta.created                 1200 non-null   object
#  3   meta.revision                1200 non-null   int64
#  4   info.city                    999 non-null    object
#  5   info.dates                   1200 non-null   object
#  6   info.gender                  1200 non-null   object
#  7   info.match_type              1200 non-null   object
#  8   info.match_type_number       80 non-null     float64
#  9   info.outcome.winner          1138 non-null   object
#  10  info.outcome.by.wickets      593 non-null    float64
#  11  info.outcome.method          112 non-null    object
#  12  info.overs                   1200 non-null   int64
# ...

# %%
filename5 = []
for file in os.listdir(r"C:\Users\72raj\Downloads\odis"):
    filename5.append(os.path.join(r'C:\Users\72raj\Downloads\odis',file))

# %%
counter = 1201
for file in tqdm(filename5):
    with open(file,'r') as f:
        x = safe_load(f)
        df = pd.json_normalize(x)
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
# Out:
#   0%|                                                                                          | 0/533 [00:00<?, ?it/s]C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\1408937220.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|▏                                                                                 | 1/533 [00:02<17:50,  2.01s/it]C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\1408937220.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1733 entries, 0 to 0
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   innings                      1733 non-null   object
#  1   meta.data_version            1733 non-null   float64
#  2   meta.created                 1733 non-null   object
#  3   meta.revision                1733 non-null   int64
#  4   info.city                    1450 non-null   object
#  5   info.dates                   1733 non-null   object
#  6   info.gender                  1733 non-null   object
#  7   info.match_type              1733 non-null   object
#  8   info.match_type_number       502 non-null    float64
#  9   info.outcome.winner          1652 non-null   object
#  10  info.outcome.by.wickets      844 non-null    float64
#  11  info.outcome.method          160 non-null    object
#  12  info.overs                   1733 non-null   int64
# ...

# %%
filename6 = []
for file in os.listdir(r"C:\Users\72raj\Downloads\Test4"):
    filename6.append(os.path.join(r'C:\Users\72raj\Downloads\Test4',file))

# %%
counter = 1734
for file in tqdm(filename6):
    with open(file,'r') as f:
        x = safe_load(f)
        df = pd.json_normalize(x)
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
# Out:
#   0%|                                                                                          | 0/150 [00:00<?, ?it/s]C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\3485668810.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|▌                                                                                 | 1/150 [00:01<02:39,  1.07s/it]C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\3485668810.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1883 entries, 0 to 0
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   innings                      1883 non-null   object
#  1   meta.data_version            1883 non-null   float64
#  2   meta.created                 1883 non-null   object
#  3   meta.revision                1883 non-null   int64
#  4   info.city                    1575 non-null   object
#  5   info.dates                   1883 non-null   object
#  6   info.gender                  1883 non-null   object
#  7   info.match_type              1883 non-null   object
#  8   info.match_type_number       502 non-null    float64
#  9   info.outcome.winner          1796 non-null   object
#  10  info.outcome.by.wickets      917 non-null    float64
#  11  info.outcome.method          171 non-null    object
#  12  info.overs                   1883 non-null   int64
# ...

# %%
backup = final_df.copy()

# %%
final_df.head()
# Out:
#                                              innings   info.city  \
# 0  [{'1st innings': {'team': 'West Indies', 'deli...     Jamaica
# 0  [{'1st innings': {'team': 'West Indies', 'deli...    Trinidad
# 0  [{'1st innings': {'team': 'Pakistan', 'deliver...  St Vincent
# 0  [{'1st innings': {'team': 'Pakistan', 'deliver...    St Lucia
# 0  [{'1st innings': {'team': 'Bangladesh', 'deliv...      London
#
#      info.dates info.gender info.match_type info.outcome.winner  info.overs  \
# 0  [2005-05-08]        male             ODI        South Africa          50
# 0  [2005-05-15]        male             ODI        South Africa          50
# 0  [2005-05-18]        male             ODI            Pakistan          50
# 0  [2005-05-22]        male             ODI            Pakistan          50
# 0  [2005-06-16]        male             ODI             England          50
#
#   info.player_of_match                   info.teams info.toss.decision  \
# ...

# %%
final_df.columns
# Out:
# Index(['innings', 'info.city', 'info.dates', 'info.gender', 'info.match_type',
#        'info.outcome.winner', 'info.overs', 'info.player_of_match',
#        'info.teams', 'info.toss.decision', 'info.toss.winner', 'info.venue',
#        'match_id'],
#       dtype='object')

# %%
final_df.drop(['info.umpires'],inplace=True,axis=1)

# %%
final_df['info.gender'].value_counts()
# Out:
# male      1682
# female     201
# Name: info.gender, dtype: int64

# %%
final_df = final_df[final_df['info.gender']=='male']
final_df.drop('info.gender',axis=1,inplace=True)
final_df
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\3734665556.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop('info.gender',axis=1,inplace=True)
#                                               innings     info.city  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...       Jamaica
# 0   [{'1st innings': {'team': 'West Indies', 'deli...      Trinidad
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...    St Vincent
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...      St Lucia
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...        London
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'South Africa', 'del...        Durban
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  Johannesburg
# ...

# %%
final_df.reset_index(inplace=True)

# %%
final_df.drop('index',axis=1,inplace=True)
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\3992430533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop('index',axis=1,inplace=True)

# %%
final_df.rename(columns={'index':'match_id'},inplace=True)
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\2106593872.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.rename(columns={'index':'match_id'},inplace=True)

# %%
final_df['match_id'] = np.arange(len(final_df))
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\216247866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['match_id'] = np.arange(len(final_df))

# %%
final_df
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'West Indies', 'deli...       Jamaica
# 1     [{'1st innings': {'team': 'West Indies', 'deli...      Trinidad
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...    St Vincent
# 3     [{'1st innings': {'team': 'Pakistan', 'deliver...      St Lucia
# 4     [{'1st innings': {'team': 'Bangladesh', 'deliv...        London
# ...                                                 ...           ...
# 1677  [{'1st innings': {'team': 'South Africa', 'del...        Durban
# 1678  [{'1st innings': {'team': 'Sri Lanka', 'delive...  Johannesburg
# 1679  [{'1st innings': {'team': 'South Africa', 'del...     Cape Town
# 1680  [{'1st innings': {'team': 'South Africa', 'del...     Centurion
# 1681  [{'1st innings': {'team': 'Afghanistan', 'deli...           NaN
#
#         info.dates info.match_type info.outcome.winner  info.overs  \
# ...

# %%
final_df.drop(['info.match_type','info.overs'],axis=1,inplace=True)
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\1356736495.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(['info.match_type','info.overs'],axis=1,inplace=True)

# %%
final_df
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'West Indies', 'deli...       Jamaica
# 1     [{'1st innings': {'team': 'West Indies', 'deli...      Trinidad
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...    St Vincent
# 3     [{'1st innings': {'team': 'Pakistan', 'deliver...      St Lucia
# 4     [{'1st innings': {'team': 'Bangladesh', 'deliv...        London
# ...                                                 ...           ...
# 1677  [{'1st innings': {'team': 'South Africa', 'del...        Durban
# 1678  [{'1st innings': {'team': 'Sri Lanka', 'delive...  Johannesburg
# 1679  [{'1st innings': {'team': 'South Africa', 'del...     Cape Town
# 1680  [{'1st innings': {'team': 'South Africa', 'del...     Centurion
# 1681  [{'1st innings': {'team': 'Afghanistan', 'deli...           NaN
#
#         info.dates info.outcome.winner info.player_of_match  \
# 0     [2005-05-08]        South Africa       [HH Dippenaar]
# ...

# %%
pickle.dump(final_df,open('cleandata.pkl','wb'))

# %%
matches = pickle.load(open('cleandata.pkl','rb'))
matches
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'West Indies', 'deli...       Jamaica
# 1     [{'1st innings': {'team': 'West Indies', 'deli...      Trinidad
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...    St Vincent
# 3     [{'1st innings': {'team': 'Pakistan', 'deliver...      St Lucia
# 4     [{'1st innings': {'team': 'Bangladesh', 'deliv...        London
# ...                                                 ...           ...
# 1677  [{'1st innings': {'team': 'South Africa', 'del...        Durban
# 1678  [{'1st innings': {'team': 'Sri Lanka', 'delive...  Johannesburg
# 1679  [{'1st innings': {'team': 'South Africa', 'del...     Cape Town
# 1680  [{'1st innings': {'team': 'South Africa', 'del...     Centurion
# 1681  [{'1st innings': {'team': 'Afghanistan', 'deli...           NaN
#
#         info.dates info.outcome.winner info.player_of_match  \
# 0     [2005-05-08]        South Africa       [HH Dippenaar]
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)
# Out:
# C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\72raj\AppData\Local\Temp\ipykernel_22640\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# ...

# %%
delivery_df.head()
# Out:
#    match_id                        teams batting_team  ball   batsman  \
# 0         2  [West Indies, South Africa]  West Indies   0.1  CH Gayle
# 1         2  [West Indies, South Africa]  West Indies   0.2  CH Gayle
# 2         2  [West Indies, South Africa]  West Indies   0.3  WW Hinds
# 3         2  [West Indies, South Africa]  West Indies   0.4  CH Gayle
# 4         2  [West Indies, South Africa]  West Indies   0.5  CH Gayle
#
#        bowler  runs player_dismissed     city                  venue
# 0  SM Pollock     0                0  Jamaica  Sabina Park, Kingston
# 1  SM Pollock     1                0  Jamaica  Sabina Park, Kingston
# 2  SM Pollock     1                0  Jamaica  Sabina Park, Kingston
# 3  SM Pollock     0                0  Jamaica  Sabina Park, Kingston
# 4  SM Pollock     0                0  Jamaica  Sabina Park, Kingston

# %%
df = delivery_df.copy

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#      match_id batting_team  ball         batsman      bowler  runs  \
# 0           2  West Indies   0.1        CH Gayle  SM Pollock     0
# 1           2  West Indies   0.2        CH Gayle  SM Pollock     1
# 2           2  West Indies   0.3        WW Hinds  SM Pollock     1
# 3           2  West Indies   0.4        CH Gayle  SM Pollock     0
# 4           2  West Indies   0.5        CH Gayle  SM Pollock     0
# ..        ...          ...   ...             ...         ...   ...
# 231      1683  Afghanistan  38.1      Amir Hamza   AG Cremer     0
# 232      1683  Afghanistan  38.2      Amir Hamza   AG Cremer     1
# 233      1683  Afghanistan  38.3  Yamin Ahmadzai   AG Cremer     0
# 234      1683  Afghanistan  38.4  Yamin Ahmadzai   AG Cremer     0
# 235      1683  Afghanistan  38.5  Yamin Ahmadzai   AG Cremer     0
#
#     player_dismissed     city                    venue  bowling_team
# 0                  0  Jamaica    Sabina Park, Kingston  South Africa
# ...

# %%
delivery_df.drop('teams',axis=1,inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['West Indies', 'Pakistan', 'Bangladesh', 'Australia', 'England',
#        'Sri Lanka', 'Africa XI', 'India', 'New Zealand', 'Zimbabwe',
#        'South Africa', 'Ireland', 'Scotland', 'Kenya', 'Bermuda',
#        'Netherlands', 'Canada', 'Asia XI', 'Afghanistan',
#        'United Arab Emirates', 'Hong Kong', 'Papua New Guinea', 'Nepal',
#        'United States of America', 'Namibia', 'Oman'], dtype=object)

# %%
teams = ['West Indies', 'Pakistan', 'Bangladesh', 'Australia', 'England',
       'Sri Lanka','India', 'New Zealand', 'Zimbabwe',
       'South Africa',]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id  batting_team  ball     batsman      bowler  runs  \
# 0           2   West Indies   0.1    CH Gayle  SM Pollock     0
# 1           2   West Indies   0.2    CH Gayle  SM Pollock     1
# 2           2   West Indies   0.3    WW Hinds  SM Pollock     1
# 3           2   West Indies   0.4    CH Gayle  SM Pollock     0
# 4           2   West Indies   0.5    CH Gayle  SM Pollock     0
# ..        ...           ...   ...         ...         ...   ...
# 302      1682  South Africa  49.5   CH Morris  RAS Lakmal     0
# 303      1682  South Africa  49.6   CH Morris  RAS Lakmal     1
# 304      1682  South Africa  49.7   CH Morris  RAS Lakmal     1
# 305      1682  South Africa  49.8  WD Parnell  RAS Lakmal     1
# 306      1682  South Africa  49.9   CH Morris  RAS Lakmal     1
#
#     player_dismissed       city                  venue  bowling_team
# 0                  0    Jamaica  Sabina Park, Kingston  South Africa
# ...

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]
output
# Out:
#      match_id  batting_team  bowling_team  ball  runs player_dismissed  \
# 0           2   West Indies  South Africa   0.1     0                0
# 1           2   West Indies  South Africa   0.2     1                0
# 2           2   West Indies  South Africa   0.3     1                0
# 3           2   West Indies  South Africa   0.4     0                0
# 4           2   West Indies  South Africa   0.5     0                0
# ..        ...           ...           ...   ...   ...              ...
# 302      1682  South Africa     Sri Lanka  49.5     0                0
# 303      1682  South Africa     Sri Lanka  49.6     1                0
# 304      1682  South Africa     Sri Lanka  49.7     1                0
# 305      1682  South Africa     Sri Lanka  49.8     1                0
# 306      1682  South Africa     Sri Lanka  49.9     1                0
#
#           city                  venue
# 0      Jamaica  Sabina Park, Kingston
# ...

# %%
pickle.dump(output,open('finaldata.pkl','wb'))

# %%
teams
# Out:
# ['West Indies',
#  'Pakistan',
#  'Bangladesh',
#  'Australia',
#  'England',
#  'Sri Lanka',
#  'India',
#  'New Zealand',
#  'Zimbabwe',
#  'South Africa']
